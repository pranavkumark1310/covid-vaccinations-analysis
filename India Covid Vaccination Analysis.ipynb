# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
india_vaccine_data = pd.read_csv('Covid-19_Daily_Vaccinations_India.csv')
statewise_vaccine_data = pd.read_csv('Covid-19_Statewise_Vaccination_India.csv')

# %% [markdown]
# ### Show India vaccination data

# %%
india_vaccine_data
# Out:
#     Unnamed: 0 location        date                      vaccine  \
# 0            0    India  15-01-2021  Covaxin, Oxford/AstraZeneca
# 1            1    India  16-01-2021  Covaxin, Oxford/AstraZeneca
# 2            2    India  17-01-2021  Covaxin, Oxford/AstraZeneca
# 3            3    India  18-01-2021  Covaxin, Oxford/AstraZeneca
# 4            4    India  19-01-2021  Covaxin, Oxford/AstraZeneca
# ..         ...      ...         ...                          ...
# 84          84    India  04-10-2021  Covaxin, Oxford/AstraZeneca
# 85          85    India  11-04-2021  Covaxin, Oxford/AstraZeneca
# 86          86    India  12-04-2021  Covaxin, Oxford/AstraZeneca
# 87          87    India  13-04-2021  Covaxin, Oxford/AstraZeneca
# 88          88    India  14-04-2021  Covaxin, Oxford/AstraZeneca
#
#                                            source_url  total_vaccinations  \
# 0   https://twitter.com/MoHFW_INDIA/status/1350459...                   0
# ...

# %% [markdown]
# ### Show statewise vaccination data

# %%
statewise_vaccine_data
# Out:
#           State/Union Territory Population (2011 census)     1st dose  \
# 0         State/Union Territory            121.06 crores  8,09,98,099
# 1   Andaman and Nicobar Islands                 3,80,581       25,363
# 2                Andhra Pradesh              4,95,77,103    30,20,007
# 3             Arunachal Pradesh                13,83,727       93,106
# 4                         Assam              3,12,05,576    11,81,704
# 5                         Bihar             10,40,99,452    36,63,711
# 6                    Chandigarh                10,55,450       89,382
# 7                  Chhattisgarh              2,55,45,198    33,22,112
# 8        Dadra and Nagar Haveli                 3,43,709       26,720
# 9                 Daman and Diu                 2,43,247       25,436
# 10                        Delhi              1,67,87,941    15,65,572
# 11                          Goa                14,58,545     1,28,428
# ...

# %%
india_vaccine_data.columns
# Out:
# Index(['Unnamed: 0', 'location', 'date', 'vaccine', 'source_url',
#        'total_vaccinations', 'total_vaccinations_per_hundred',
#        'people_vaccinated', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated', 'people_fully_vaccinated_per_hundred',
#        'daily_vaccinations', 'daily_change_in_vaccinations',
#        'daily_vaccinations_per_million'],
#       dtype='object')

# %%
statewise_vaccine_data.columns
# Out:
# Index(['State/Union Territory', 'Population (2011 census)', '1st dose',
#        '2nd dose', 'Cumulative doses administered',
#        'Percentage of people given atleast one  dose',
#        'Percentage of people fully vaccinated'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
india_vaccine_data.head()
# Out:
#    Unnamed: 0 location        date                      vaccine  \
# 0           0    India  15-01-2021  Covaxin, Oxford/AstraZeneca
# 1           1    India  16-01-2021  Covaxin, Oxford/AstraZeneca
# 2           2    India  17-01-2021  Covaxin, Oxford/AstraZeneca
# 3           3    India  18-01-2021  Covaxin, Oxford/AstraZeneca
# 4           4    India  19-01-2021  Covaxin, Oxford/AstraZeneca
#
#                                           source_url  total_vaccinations  \
# 0  https://twitter.com/MoHFW_INDIA/status/1350459...                   0
# 1  https://twitter.com/MoHFW_INDIA/status/1350459...              191181
# 2  https://twitter.com/MoHFW_INDIA/status/1350815...              224301
# 3                          https://www.mohfw.gov.in/              454049
# 4                          https://www.mohfw.gov.in/              674835
#
#    total_vaccinations_per_hundred  people_vaccinated  \
# 0                            0.00                  0
# ...

# %%
india_vaccine_data.tail()
# Out:
#     Unnamed: 0 location        date                      vaccine  \
# 84          84    India  04-10-2021  Covaxin, Oxford/AstraZeneca
# 85          85    India  11-04-2021  Covaxin, Oxford/AstraZeneca
# 86          86    India  12-04-2021  Covaxin, Oxford/AstraZeneca
# 87          87    India  13-04-2021  Covaxin, Oxford/AstraZeneca
# 88          88    India  14-04-2021  Covaxin, Oxford/AstraZeneca
#
#                                            source_url  total_vaccinations  \
# 84  http://mohfw.gov.in/pdf/CumulativeCOVIDVaccina...           101595147
# 85  http://mohfw.gov.in/pdf/CumulativeCOVIDVaccina...           104528565
# 86  http://mohfw.gov.in/pdf/CumulativeCOVIDVaccina...           108533085
# 87  https://www.mohfw.gov.in/pdf/CumulativeCOVIDVa...           111179578
# 88  http://mohfw.gov.in/pdf/CumulativeCOVIDVaccina...           114493238
#
#     total_vaccinations_per_hundred  people_vaccinated  \
# 84                            7.36           88885961
# ...

# %%
statewise_vaccine_data.head()
# Out:
#          State/Union Territory Population (2011 census)     1st dose  \
# 0        State/Union Territory            121.06 crores  8,09,98,099
# 1  Andaman and Nicobar Islands                 3,80,581       25,363
# 2               Andhra Pradesh              4,95,77,103    30,20,007
# 3            Arunachal Pradesh                13,83,727       93,106
# 4                        Assam              3,12,05,576    11,81,704
#
#       2nd dose Cumulative doses administered  \
# 0  1,08,83,431                   9,18,81,530
# 1        5,403                        30,766
# 2     4,76,360                     34,96,367
# 3       27,291                      1,20,397
# 4     2,23,370                     14,05,074
#
#   Percentage of people given atleast one  dose  \
# 0                                        6.69%
# 1                                        6.66%
# 2                                        6.09%
# 3                                        6.73%
# ...

# %%
statewise_vaccine_data.tail()
# Out:
#    State/Union Territory Population (2011 census)   1st dose   2nd dose  \
# 34               Tripura                36,73,917   6,98,009     87,409
# 35         Uttar Pradesh             19,98,12,341  69,50,868  11,93,098
# 36           Uttarakhand              1,00,86,292  10,15,354   1,67,694
# 37           West Bengal              9,12,76,115  64,65,014   8,46,672
# 38         Miscellaneous                      NaN  14,88,931   7,78,111
#
#    Cumulative doses administered Percentage of people given atleast one  dose  \
# 34                      7,85,418                                       18.99%
# 35                     81,43,966                                        3.48%
# 36                     11,83,048                                       10.06%
# 37                     73,11,686                                        7.08%
# 38                     22,67,042                                          NaN
#
#    Percentage of people fully vaccinated
# ...

# %%
india_vaccine_data.describe()
# Out:
#        Unnamed: 0  total_vaccinations  total_vaccinations_per_hundred  \
# count   89.000000        8.900000e+01                       89.000000
# mean    44.000000        3.058592e+07                        2.216404
# std     25.836021        3.247053e+07                        2.352958
# min      0.000000        0.000000e+00                        0.000000
# 25%     22.000000        5.775322e+06                        0.420000
# 50%     44.000000        1.485414e+07                        1.080000
# 75%     66.000000        5.084129e+07                        3.680000
# max     88.000000        1.144932e+08                        8.300000
#
#        people_vaccinated  people_vaccinated_per_hundred  \
# count       8.900000e+01                      89.000000
# mean        2.640329e+07                       1.913034
# std         2.808493e+07                       2.035282
# min         0.000000e+00                       0.000000
# ...

# %%
statewise_vaccine_data.describe()
# Out:
#        State/Union Territory Population (2011 census)   1st dose  2nd dose  \
# count                     39                       38         39        39
# unique                    39                       38         39        39
# top                  Haryana                10,55,450  10,15,354  1,78,687
# freq                       1                        1          1         1
#
#        Cumulative doses administered  \
# count                             39
# unique                            39
# top                        21,34,827
# freq                               1
#
#        Percentage of people given atleast one  dose  \
# count                                            38
# unique                                           38
# top                                          11.67%
# freq                                              1
#
#        Percentage of people fully vaccinated
# count                                     38
# ...

# %%
india_vaccine_data.isnull().sum()
# Out:
# Unnamed: 0                             0
# location                               0
# date                                   0
# vaccine                                0
# source_url                             0
# total_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated                      0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated                0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations                     0
# daily_change_in_vaccinations           0
# daily_vaccinations_per_million         0
# dtype: int64

# %%
statewise_vaccine_data.isnull().sum()
# Out:
# State/Union Territory                           0
# Population (2011 census)                        1
# 1st dose                                        0
# 2nd dose                                        0
# Cumulative doses administered                   0
# Percentage of people given atleast one  dose    1
# Percentage of people fully vaccinated           1
# dtype: int64

# %%
print(india_vaccine_data.shape)
print(statewise_vaccine_data.shape)
# Out:
# (89, 14)
# (39, 7)

# %%
india_vaccine_data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# Length: 89, dtype: bool

# %%
india_vaccine_data.duplicated().sum()
# Out:
# 0

# %%
statewise_vaccine_data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# dtype: bool

# %%
statewise_vaccine_data.duplicated().sum()
# Out:
# 0

# %%
statewise_vaccine_data.dtypes
# Out:
# State/Union Territory                           object
# Population (2011 census)                        object
# 1st dose                                        object
# 2nd dose                                        object
# Cumulative doses administered                   object
# Percentage of people given atleast one  dose    object
# Percentage of people fully vaccinated           object
# dtype: object

# %% [markdown]
# ### Dropping column 'Unamed: 0' and analysing the whole dataset using lineplot.

# %%
india_vaccine_data.drop('Unnamed: 0', inplace=True, axis=1)

# %%
sns.lineplot(data=india_vaccine_data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Vaccination trends in India between 10-04-2021 and 13-04-2021

# %%
plt.figure(figsize=(16,10))
new_data = india_vaccine_data[(india_vaccine_data['date'] >= '10-04-2021') & (india_vaccine_data['date'] <= '17-04-2021')]
plt.plot(new_data['date'], new_data['total_vaccinations']/1000)

# %%
sns.pairplot(data=new_data)

# %% [markdown]
# ### Line graph for total vaccinations vs People Fully vaccinated

# %%
plt.figure(figsize=(16,10))
plt.plot(new_data['total_vaccinations']/1000, new_data['people_fully_vaccinated']/1000)
plt.title('Total vaccinations vs People Fully vaccinated')
plt.xlabel('Total Vaccinations')
plt.ylabel('People Fully Vaccinated')
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.plot(new_data['people_vaccinated_per_hundred']/1000, new_data['people_fully_vaccinated_per_hundred']/1000)
plt.title('Vaccinated per hundred vs Fully vaccinated per hundred')
plt.xlabel('Vaccinations per hundred')
plt.ylabel('Fully Vaccinated per hundred')
plt.show()

# %%
f, ax = plt.subplots(figsize=(16, 16))
sns.scatterplot(x=india_vaccine_data.total_vaccinations/1000, y=india_vaccine_data.people_fully_vaccinated/1000,
                palette="ch:r=-.2,d=.3_r",
                sizes=(1, 10), linewidth=0,
                data=india_vaccine_data,ax=ax)
# Out:
# <AxesSubplot:xlabel='total_vaccinations', ylabel='people_fully_vaccinated'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(new_data.date, new_data.daily_vaccinations/1000, palette='CMRmap_r')
plt.title("Vaccination in India")
# Out:
# C:\Users\Pranav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Vaccination in India')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(new_data.date, new_data.daily_change_in_vaccinations/1000)
# Out:
# C:\Users\Pranav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='date', ylabel='daily_change_in_vaccinations'>

# %%
plt.figure(figsize=(20,10))
sns.lineplot(new_data.date, new_data.total_vaccinations/1000)
# Out:
# C:\Users\Pranav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='date', ylabel='total_vaccinations'>
